# %% [markdown]
# ## File Operations - Synopsis
#
# In this notebook we will earn an important skill, how to read and write text files. In order to do that, we will cover:
#
# 1. How files are organized on a computer and how to view/find file locations with terminal commands from the notebook
# 2. How to open a file and read it
# 3. How to open a file and write text to it.

# %% [markdown]
# ### Creating a text file
#
# As a first step, let us see how we can create a text file
#
# **Before** running the below code cell, go to your folder and see if you have any file called **`testfile.txt`?**
#
# There should be none in the beginning.
#
# Syntax for opening file:
# **file = open('filename', 'mode')**
# > filename - enter your filename
# >
# > mode - 'a', 'r', 'w', 'x'
#
#     "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#     "a" - Append - Opens a file for appending, creates the file if it does not exist
#     "w" - Write - Opens a file for writing, creates the file if it does not exist
#     "x" - Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
#
#     "t" - Text - Default value. Text mode
#     "b" - Binary - Binary mode (e.g. images)

# %% [markdown]
# **Before** running the below code cell, go to your folder and see if you have any file called **`testfile.txt`?**
#
# There should be none in the beginning

# %% [markdown]
# ### How to view & find file locations from notebook, run below cell:

# %%
# !dir

# %%
file =
# w is for write-mode. By deafult, file opens in read-mode.

# The above code will open an existing file in writing mode.
# If the file doesn't exist, it will create a new file in the directory.

file.write("Hello, My name is John! \n")  #\n actually indicates a next line!
file.write("I want to open a new bank account \n")
file.write("Who is the best person to contact? \n")
file.write("Please let me know.")

file.close() # Since you opened the file in editable mode, you must close it.

# Check your directory/folder, you should be able to see a file created there.

# %% [markdown]
# ### Reading the created text file

# %%
file =
# r is for read mode

print(file.read())
# read() is to read all characters

# %%
file = open("testfile.txt", "r")
# r is for read mode

print(file.read(5))
# reading only 5 characters from start

# %% [markdown]
# ### Reading the text file line by line

# %%
file = open("testfile.txt", "r")
# r is for read mode

print(file.
# readline() prints one line at a time

# %% [markdown]
# After opening the file, it will print the 1st line only,
#
# To print next lines, we will need to call `readline()` again.

# %%
print(file.readline())

# It will print the next lines every time we run the code.

# %% [markdown]
# When all lines are printed one by one, it won't show any more line.
#
# You will have to open the file in r mode again to read lines.

# %% [markdown]
# To print all lines at once, we can get a list of lines using the method `readlines()`

# %%
file = open("testfile.txt", "r")
print(file.

# this will give list of all lines, and includes the separators like \n, \t etc.

# %% [markdown]
# ### Reading all the lines in the text file together

# %%
file = open("testfile.txt", "r")
all_lines = file.readlines() # creating a list of all lines
print(all_lines)

# %%
for i in all_lines:
    print(i)

# %%
# printing 2nd item or index 1 from the list
print(

# %% [markdown]
# ### Overwriting existing files
#
# If the file already exists, opening it in w-mode will overwrite its content.

# %%
file =

file.write("More Lines \n")
file.write("This is the old text file \n")

file.close()

# %%
file = open("testfile.txt", "r")
print(file.read())

# %% [markdown]
# ### Appending to a file
#
# Append mode (`a`) will not overwrite. It will add lines after the existing lines.

# %%
file = open("testfile.txt", "a")  # a is for append

file.write("Some more Lines \n")
file.write("We have appended the file. \n")

file.close()

# %%
file = open("testfile.txt", "r")
print(file.read())

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Question 1:
#
# Create a file and write 10 lines in the file as follows:
#
# i am number 1 <br>
# i am number 2 <br>
# . <br>
# . <br>
# . <br>
# .
# i am number 10
#
# and open and read all the lines of the file

# %% [markdown]
# ### Question 2:
#
# Look at the below code, this is from Flow Control chapter:
#
#     def Larger(x, y):
#         if x > y:
#             print(x, "is larger.")
#         elif x < y:
#             print(y, "is larger.")
#         else:
#             print("Both are equal.")
#
#     def FindSquare(x,y):
#         print("Square of", x, "is", x**2)
#         print("Square of", y, "is", y**2)
#
#
#     num1 = float(input("Enter 1st number: "))
#     num2 = float(input("Enter 2nd number: "))
#
#     print("\nWhat do you want to do? \n")
#     print("Enter 1 to find the larger of the two numbers.")
#     print("Enter 2 to find the squared value of the two numbers.\n")
#
#     choice = int(input("Your choice: "))
#     print(choice)
#
#     if choice == 1:
#         Larger(num1, num2)
#
#     elif choice == 2:
#         FindSquare(num1, num2)
#
#     else:
#         print("Invalid choice.")
#
#
# **Task:** Modify it to create a text file that records your output.
